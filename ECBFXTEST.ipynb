# %% [markdown]
# <a href="https://colab.research.google.com/github/DPK-VT/MLTESTS/blob/main/ECBFXTEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Replace with your actual file path or upload in Colab
file_path = 'ECB_exchange_rates_march31.xlsx'

# Load the Excel file
df = pd.read_excel(file_path)

# Preview the structure
df.head()
# Out:
#         Date     USD     JPY      GBP     CHF     AUD
# 0 2025-03-31  1.0815  161.60  0.83536  0.9531  1.7318
# 1 2025-03-28  1.0797  162.64  0.83358  0.9525  1.7120
# 2 2025-03-27  1.0785  162.55  0.83318  0.9524  1.7101
# 3 2025-03-26  1.0788  162.20  0.83623  0.9532  1.7077
# 4 2025-03-25  1.0825  162.32  0.83565  0.9539  1.7123
